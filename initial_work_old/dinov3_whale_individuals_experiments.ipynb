# %% [markdown]
# # DINOv3 Whale Individuals Experiments
# Minimal notebook to load local images, compute DINOv3 embeddings + foreground masks, cluster by pose/individual, show examples with overlays, and export grouped images.

# %% [markdown]
# ## 1. Install (if needed)
# Uncomment to install dependencies.

# %%
# !pip install --upgrade pip
# !pip install fiftyone jupyter git+https://github.com/huggingface/transformers huggingface_hub torch pillow scikit-learn numpy

# %% [markdown]
# ## 2. Imports and dataset load from local test set
# Loads images recursively from the 2025-3-24 folder under /home/sat3737/Test.

# %%
import fiftyone as fo
from pathlib import Path

DINO_REPO_PATH = Path('/home/sat3737/dinov3')
DINO_WEIGHTS_PATH = DINO_REPO_PATH / 'weights' / 'dinov3_vitb16_pretrain_lvd1689m-73cec8be.pth'
DATA_ROOT = Path('/home/sat3737/Test/Lightroom images/Topside research/2025 Research/2025-3-24')

IMAGE_EXTS = {'.jpg', '.jpeg', '.png', '.cr2', '.cr3', '.nef', '.arw', '.dng'}
image_paths = sorted(
    str(p)
    for p in DATA_ROOT.rglob('*')
    if p.suffix.lower() in IMAGE_EXTS
)
print(f'Found {len(image_paths)} images under {DATA_ROOT}')
print(f'Using local DINOv3 repo: {DINO_REPO_PATH}')
print(f'Using local DINOv3 weights: {DINO_WEIGHTS_PATH}')

if fo.dataset_exists('whale-local-dinov3-exp'):
    fo.delete_dataset('whale-local-dinov3-exp')
dataset = fo.Dataset.from_images(image_paths, name='whale-local-dinov3-exp')
dataset.persistent = True
dataset
# Out:
# Found 409 images under /home/sat3737/Test/Lightroom images/Topside research/2025 Research/2025-3-24
# Using local DINOv3 repo: /home/sat3737/dinov3
# Using local DINOv3 weights: /home/sat3737/dinov3/weights/dinov3_vitb16_pretrain_lvd1689m-73cec8be.pth
#    0% ||----------------|   1/409 [7.2ms elapsed, 3.0s remaining, 137.9 samples/s]
#  100% |█████████████████| 409/409 [50.4ms elapsed, 0s remaining, 8.1K samples/s]
# Name:        whale-local-dinov3-exp
# Media type:  image
# Num samples: 409
# Persistent:  True
# Tags:        []
# Sample fields:
#     id:               fiftyone.core.fields.ObjectIdField
#     filepath:         fiftyone.core.fields.StringField
#     tags:             fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:         fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     created_at:       fiftyone.core.fields.DateTimeField
#     last_modified_at: fiftyone.core.fields.DateTimeField

# %% [markdown]
# ## 3. Build DINOv3 model wrapper

# %%
import sys
import numpy as np
import rawpy
import torch
from PIL import Image, ImageOps
from torchvision import transforms

if str(DINO_REPO_PATH) not in sys.path:
    sys.path.insert(0, str(DINO_REPO_PATH))

from dinov3.hub.backbones import dinov3_vitb16

device = 'cuda' if torch.cuda.is_available() else 'cpu'
transformers_model = dinov3_vitb16(
    pretrained=True,
    weights=str(DINO_WEIGHTS_PATH),
).to(device).eval()

dino_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
])

RAW_EXTS = {'.cr2', '.cr3', '.nef', '.arw', '.dng'}

def load_rgb_image(path: str) -> Image.Image:
    p = Path(path)
    if p.suffix.lower() in RAW_EXTS:
        with rawpy.imread(str(p)) as raw:
            rgb = raw.postprocess(use_camera_wb=True, no_auto_bright=True, output_bps=8)
        return Image.fromarray(rgb).convert('RGB')
    return ImageOps.exif_transpose(Image.open(path).convert('RGB'))

# %% [markdown]
# ## 4. Compute embeddings

# %%
if not dataset.has_field('embeddings_dinov3'):
    dataset.add_sample_field('embeddings_dinov3', fo.VectorField)

@torch.inference_mode()
def compute_cls_embedding(path: str):
    img = load_rgb_image(path)
    inp = dino_transform(img).unsqueeze(0).to(device)
    feats = transformers_model.forward_features(inp)
    return feats['x_norm_clstoken'][0].detach().cpu().numpy()

skipped = 0
for sample in dataset.iter_samples(autosave=True, progress=True):
    try:
        sample['embeddings_dinov3'] = compute_cls_embedding(sample.filepath)
    except Exception:
        sample['embeddings_dinov3'] = None
        skipped += 1

print(f"wrote embeddings to 'embeddings_dinov3'. skipped: {skipped}")
# Out:
#    0% |/----------------|   0/409 [377.1ms elapsed, ? remaining, ? samples/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 13
#      11         sample['embeddings_dinov3'] = compute_cls_embedding(sample.filepath)
#      12     except Exception:
# ---> 13         sample['embeddings_dinov3'] = None
#      14         skipped += 1
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     123 with ctx_factory():
# --> 124     return func(*args, **kwargs)
#
# Cell In[20], line 3, in compute_cls_embedding(path)
#       1 @torch.inference_mode()
#       2 def compute_cls_embedding(path: str):
# ----> 3     img = load_rgb_image(path)
#       4     inp = dino_transform(img).unsqueeze(0).to(device)
#
# Cell In[19], line 31, in load_rgb_image(path)
#      29     if p.suffix.lower() in RAW_EXTS:
#      30         with rawpy.imread(str(p)) as raw:
# ---> 31             rgb = raw.postprocess(use_camera_wb=True, auto_bright=False, output_bps=8)
#      32         return Image.fromarray(rgb).convert('RGB')
#
# File rawpy/_rawpy.pyx:1052, in rawpy._rawpy.RawPy.postprocess()
# -> 1052 'Could not get source, probably due dynamically evaluated source code.'
#
# File rawpy/_rawpy.pyx:950, in rawpy._rawpy.RawPy.dcraw_process()
# --> 950 'Could not get source, probably due dynamically evaluated source code.'
#
# File rawpy/_rawpy.pyx:1233, in rawpy._rawpy.Params.__init__()
# -> 1233 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: __init__() got an unexpected keyword argument 'auto_bright'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 13
#       9 for sample in dataset.iter_samples(autosave=True, progress=True):
#      10     try:
#      11         sample['embeddings_dinov3'] = compute_cls_embedding(sample.filepath)
#      12     except Exception:
# ---> 13         sample['embeddings_dinov3'] = None
#      14         skipped += 1
#      15
#      16 print(f"wrote embeddings to 'embeddings_dinov3'. skipped: {skipped}")
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/sample.py:71, in _SampleMixin.__setitem__(self, field_name, value)
#      68     return
#      70 self._secure_media(field_name, value)
# ---> 71 super().__setitem__(field_name, value)
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/document.py:74, in _Document.__setitem__(self, field_name, value)
#      73 def __setitem__(self, field_name, value):
# ---> 74     self.set_field(field_name, value)
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/sample.py:123, in _SampleMixin.set_field(self, field_name, value, create, validate, dynamic)
#     114     self.frames.update(
#     115         value,
#     116         expand_schema=create,
#     117         validate=validate,
#     118         dynamic=dynamic,
#     119     )
#     121     return
# --> 123 super().set_field(
#     124     field_name,
#     125     value,
#     126     create=create,
#     127     validate=validate,
#     128     dynamic=dynamic,
#     129 )
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/document.py:194, in _Document.set_field(self, field_name, value, create, validate, dynamic)
#     172 def set_field(
#     173     self,
#     174     field_name,
#    (...)    178     dynamic=False,
#     179 ):
#     180     """Sets the value of a field of the document.
#     181
#     182     Args:
#    (...)    192         AttributeError: if the field does not exist and ``create == False``
#     193     """
# --> 194     self._doc.set_field(
#     195         field_name,
#     196         value,
#     197         create=create,
#     198         validate=validate,
#     199         dynamic=dynamic,
#     200     )
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/odm/mixins.py:176, in DatasetMixin.set_field(self, field_name, value, create, validate, dynamic, _enforce_read_only)
#     174 if field is None:
#     175     if create:
# --> 176         self.add_implied_field(
#     177             field_name,
#     178             value,
#     179             expand_schema=True,
#     180             validate=validate,
#     181             dynamic=dynamic,
#     182         )
#     183     else:
#     184         raise ValueError(
#     185             "%s has no field '%s'" % (self._doc_name(), field_name)
#     186         )
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/odm/mixins.py:489, in DatasetMixin.add_implied_field(cls, path, value, expand_schema, dynamic, recursive, validate)
#     455 @classmethod
#     456 def add_implied_field(
#     457     cls,
#    (...)    463     validate=True,
#     464 ):
#     465     """Adds the field or embedded field to the document, if necessary,
#     466     inferring the field type from the provided value.
#     467
#    (...)    487             existing field of the same name
#     488     """
# --> 489     field = create_implied_field(path, value, dynamic=dynamic)
#     491     return cls.merge_field_schema(
#     492         {path: field},
#     493         expand_schema=expand_schema,
#     494         recursive=recursive,
#     495         validate=validate,
#     496     )
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/odm/utils.py:303, in create_implied_field(path, value, dynamic)
#     292 """Creates the field for the given value.
#     293
#     294 Args:
#    (...)    300     a :class:`fiftyone.core.fields.Field`
#     301 """
#     302 field_name = path.rsplit(".", 1)[-1]
# --> 303 kwargs = get_implied_field_kwargs(value, dynamic=dynamic)
#     304 return create_field(field_name, **kwargs)
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/odm/utils.py:437, in get_implied_field_kwargs(value, dynamic)
#     434 if isinstance(value, dict):
#     435     return {"ftype": fof.DictField}
# --> 437 raise TypeError(
#     438     "Cannot infer an appropriate field type for value '%s'" % value
#     439 )
#
# TypeError: Cannot infer an appropriate field type for value 'None'

# %% [markdown]
# ## 5. PCA/CLS foreground masks + heatmaps

# %%
import numpy as np
import torch
import torch.nn.functional as F
from fiftyone import Segmentation, Heatmap

def build_pca_fg_masks(
    dataset: fo.Dataset,
    field: str = 'pca_fg',
    heatmap_field: str | None = 'pca_fg_heat',
    thresh: float = 0.5,
    smooth_k: int = 3,
):
    if not dataset.has_field(field):
        dataset.add_sample_field(field, fo.EmbeddedDocumentField, embedded_doc_type=fo.Segmentation)
    if heatmap_field and not dataset.has_field(heatmap_field):
        dataset.add_sample_field(heatmap_field, fo.EmbeddedDocumentField, embedded_doc_type=fo.Heatmap)
    mt = dict(dataset.mask_targets or {})
    mt[field] = {0: 'background', 1: 'foreground'}
    dataset.mask_targets = mt
    dataset.save()

    @torch.inference_mode()
    def _fg_mask(path: str):
        img = load_rgb_image(path)
        W0, H0 = img.size
        inp = dino_transform(img).unsqueeze(0).to(device)
        feats = transformers_model.forward_features(inp)
        patches = feats['x_norm_patchtokens'][0].float()
        cls = feats['x_norm_clstoken'][0:1].float()

        n_patches = patches.shape[0]
        gh = gw = int(round(n_patches ** 0.5))
        if gh * gw != n_patches:
            raise ValueError(f'Cannot reshape {n_patches} patch tokens into a square grid')

        sims = (F.normalize(patches, dim=1) @ F.normalize(cls, dim=1).T).squeeze(1)
        fg = sims.detach().cpu().view(gh, gw)

        fg01 = (fg - fg.min()) / (fg.max() - fg.min() + 1e-8)
        if smooth_k and smooth_k > 1:
            fg01 = F.avg_pool2d(fg01.unsqueeze(0).unsqueeze(0), smooth_k, 1, smooth_k // 2).squeeze()
        mask_small = (fg01 > thresh).to(torch.uint8).numpy()
        mask_full = Image.fromarray(mask_small * 255).resize((W0, H0), Image.NEAREST)
        soft_full = Image.fromarray((fg01.numpy() * 255).astype(np.uint8)).resize((W0, H0), Image.BILINEAR)
        mask = (np.array(mask_full) > 127).astype(np.uint8)
        soft = np.array(soft_full).astype(np.float32) / 255.0
        return mask, soft

    skipped = 0
    for s in dataset.iter_samples(autosave=True, progress=True):
        try:
            msk, soft = _fg_mask(s.filepath)
            s[field] = Segmentation(mask=msk)
            if heatmap_field:
                s[heatmap_field] = Heatmap(map=soft)
        except Exception:
            s[field] = None
            if heatmap_field:
                s[heatmap_field] = None
            skipped += 1

    msg = "wrote masks to '{field}'".format(field=field)
    if heatmap_field:
        msg += " and heatmaps to '{hf}'".format(hf=heatmap_field)
    msg += f". skipped: {skipped}"
    print(msg)

build_pca_fg_masks(dataset)
# Out:
#  100% |█████████████████████| 0/0 [1.2ms elapsed, ? remaining, ? samples/s]
# wrote masks to 'pca_fg' and heatmaps to 'pca_fg_heat'. skipped: 0

# %% [markdown]
# ## 6. Foreground-only CLS embeddings

# %%
import numpy as np
from PIL import Image

def masked_cls_embedding(path, mask, model, transform, device=None):
    if mask is None:
        return None
    device = device or ('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    img = load_rgb_image(path)
    m = mask
    if m.shape != (img.height, img.width):
        m = np.array(Image.fromarray(m.astype(np.uint8) * 255).resize((img.width, img.height), Image.NEAREST)) > 127
    arr = np.array(img)
    arr[~m] = 0
    masked_img = Image.fromarray(arr)
    inputs = transform(masked_img).unsqueeze(0).to(device)
    with torch.inference_mode():
        feats = model.forward_features(inputs)
    cls = feats['x_norm_clstoken'][0].detach().cpu().numpy()
    return cls

device = 'cuda' if torch.cuda.is_available() else 'cpu'
transformers_model = transformers_model.to(device).eval()

for sample in dataset.iter_samples(autosave=True, progress=True):
    seg = sample['pca_fg'] if sample.has_field('pca_fg') else None
    mask = None if seg is None else seg.mask
    emb = masked_cls_embedding(sample.filepath, mask, transformers_model, dino_transform, device=device)
    sample['embeddings_dinov3_fg'] = emb
# Out:
#  100% |█████████████████████| 0/0 [757.2us elapsed, ? remaining, ? samples/s]

# %% [markdown]
# ## 7. Cluster poses and individuals (KMeans on foreground embeddings)

# %%
import numpy as np
from sklearn.cluster import KMeans
from fiftyone import ViewField as F

# Pose clustering
pose_k = 3
embs = dataset.values('embeddings_dinov3_fg')
ids = dataset.values('id')
mask = [e is not None for e in embs]
X = np.stack([e for e,m in zip(embs,mask) if m], axis=0) if any(mask) else None
ids_masked = [i for i,m in zip(ids,mask) if m]
if X is None or len(ids_masked) < 2:
    print('Not enough embeddings for pose clustering.')
else:
    k = min(pose_k, max(2, len(ids_masked)))
    kmeans = KMeans(n_clusters=k, random_state=51, n_init='auto').fit(X)
    for sid, lbl in zip(ids_masked, kmeans.labels_.tolist()):
        sample = dataset[sid]
        sample['pose_cluster'] = int(lbl)
        sample.save()
    print('Pose clusters sizes:', dict(zip(*np.unique(kmeans.labels_, return_counts=True))))

# Individual clustering per pose
individual_k = 5
pose_vals = dataset.values('pose_cluster') if dataset.has_field('pose_cluster') else []
if not pose_vals:
    print('No pose_cluster labels available; run pose clustering first.')
else:
    for pose_id in sorted(set(p for p in pose_vals if p is not None)):
        pose_embs = [e for e,p in zip(embs, pose_vals) if p == pose_id and e is not None]
        pose_ids  = [i for i,p in zip(ids,  pose_vals) if p == pose_id and p is not None]
        if len(pose_embs) < 2:
            continue
        k = min(individual_k, max(2, len(pose_embs)))
        kmeans = KMeans(n_clusters=k, random_state=pose_id, n_init='auto').fit(np.stack(pose_embs))
        for sid, lbl in zip(pose_ids, kmeans.labels_.tolist()):
            sample = dataset[sid]
            sample['individual_cluster'] = int(lbl)
            sample.save()
    print('Done assigning individual_cluster labels per pose.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 7
#       3 from fiftyone import ViewField as F
#       4
#       5 # Pose clustering
#       6 pose_k = 3
# ----> 7 embs = dataset.values('embeddings_dinov3_fg')
#       8 ids = dataset.values('id')
#       9 mask = [e is not None for e in embs]
#      10 X = np.stack([e for e,m in zip(embs,mask) if m], axis=0) if any(mask) else None
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:9956, in SampleCollection.values(self, field_or_expr, expr, missing_value, unwind, _allow_missing, _big_result, _raw, _field, _enforce_natural_order)
#    9952             _raw=_raw,
#    9953             _field=_field,
#    9954             _lazy=False,
#    9955         )
# -> 9956         return self._make_and_aggregate(make, field_or_expr)
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:11828, in SampleCollection._make_and_aggregate(self, make, args, _generator)
#   11824                 return agg
#   11825             # when not using a generator, we exhaust the cursor and load all
#   11826             # the results into memory at once here
#   11827             return tuple(agg)
# > 11828         return self.aggregate(
#   11829             make(args),
#   11830         )
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:11418, in SampleCollection.aggregate(self, aggregations, _mongo)
#   11414         pipelines = []
#   11415
#   11416         # Build batch pipeline
#   11417         if batch_aggs:
# > 11418             pipeline = self._build_batch_pipeline(batch_aggs)
#   11419             pipelines.append(pipeline)
#   11420
#   11421         # Build big pipelines
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:11616, in SampleCollection._build_batch_pipeline(self, aggs_map)
#   11612         group_slices = set()
#   11613         for idx, aggregation in aggs_map.items():
#   11614             big_field = "value%d" % idx
#   11615
# > 11616             _pipeline = aggregation.to_mongo(self, big_field=big_field)
#   11617             attach_frames |= aggregation._needs_frames(self)
#   11618             _group_slices = aggregation._needs_group_slices(self)
#   11619             if _group_slices:
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/aggregations.py:2917, in Values.to_mongo(self, sample_collection, big_field, context)
#    2910 def to_mongo(self, sample_collection, big_field="values", context=None):
#    2911     (
#    2912         path,
#    2913         pipeline,
#    2914         list_fields,
#    2915         id_to_str,
#    2916         field,
# -> 2917     ) = _parse_field_and_expr(
#    2918         sample_collection,
#    2919         self._field_name,
#    2920         expr=self._expr,
#    2921         unwind=self._unwind,
#    2922         allow_missing=self._allow_missing,
#    2923         context=context,
#    2924     )
#    2926     self._field = self._manual_field or field
#    2927     self._big_field = big_field
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/aggregations.py:3089, in _parse_field_and_expr(sample_collection, field_name, expr, safe, unwind, allow_missing, context, optimize)
#    3080 else:
#    3081     pipeline = []
#    3083 (
#    3084     path,
#    3085     is_frame_field,
#    3086     unwind_list_fields,
#    3087     other_list_fields,
#    3088     id_to_str,
# -> 3089 ) = sample_collection._parse_field_name(
#    3090     field_name,
#    3091     auto_unwind=auto_unwind,
#    3092     omit_terminal_lists=omit_terminal_lists,
#    3093     allow_missing=allow_missing,
#    3094 )
#    3096 if found_expr:
#    3097     # We have no way of knowing what type `expr` outputs...
#    3098     id_to_str = False
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:11962, in SampleCollection._parse_field_name(self, field_name, auto_unwind, omit_terminal_lists, allow_missing, new_field)
#   11958         omit_terminal_lists=False,
#   11959         allow_missing=False,
#   11960         new_field=None,
#   11961     ):
# > 11962         return _parse_field_name(
#   11963             self,
#   11964             field_name,
#   11965             auto_unwind,
#
# File ~/Dinov3-WhaleID/.venv/lib/python3.12/site-packages/fiftyone/core/collections.py:13104, in _parse_field_name(sample_collection, field_name, auto_unwind, omit_terminal_lists, allow_missing, new_field)
#   13100         root_field_name = field_name.split(".", 1)[0]
#   13101
#   13102         if sample_collection.get_field(prefix + root_field_name) is None:
#   13103             ftype = "frame field" if is_frame_field else "field"
# > 13104             raise ValueError(
#   13105                 "%s has no %s '%s'"
#   13106                 % (
#   13107                     sample_collection.__class__.__name__,
#
# ValueError: Dataset has no field 'embeddings_dinov3_fg'

# %% [markdown]
# ## 8. Visualize pose examples (mask overlay)

# %%
import matplotlib.pyplot as plt
from PIL import Image
from fiftyone import ViewField as F

max_poses = 3
max_per_pose = 5
pose_vals = dataset.values('pose_cluster') if dataset.has_field('pose_cluster') else []
if not pose_vals:
    print('No pose_cluster field; run clustering first.')
else:
    pose_ids = sorted(set(p for p in pose_vals if p is not None))[:max_poses]
    for pid in pose_ids:
        view = dataset.match(F('pose_cluster') == pid)
        samples = list(view.shuffle(seed=pid).limit(max_per_pose))
        print(f'Pose {pid}: showing {len(samples)} of {view.count()}')
        if len(samples) == 0:
            continue
        fig, axes = plt.subplots(1, len(samples), figsize=(4*len(samples), 4))
        if len(samples) == 1:
            axes = [axes]
        for ax, sample in zip(axes, samples):
            img = Image.open(sample.filepath).convert('RGB')
            ax.imshow(img)
            mask = None
            if sample.has_field('pca_fg') and sample['pca_fg'] is not None:
                mask = sample['pca_fg'].mask
            if mask is not None:
                ax.imshow(mask, cmap='inferno', alpha=0.35)
            ax.set_xticks([]); ax.set_yticks([])
        plt.show()

# %% [markdown]
# ## 9. Visualize individual examples (heatmap overlay)

# %%
import matplotlib.pyplot as plt
from PIL import Image
from fiftyone import ViewField as F
import numpy as np

max_individuals = 5
max_per_individual = 5
if not dataset.has_field('individual_cluster'):
    print('No individual_cluster field; run individual clustering first.')
else:
    clusters = sorted(set(c for c in dataset.values('individual_cluster') if c is not None))[:max_individuals]
    for cid in clusters:
        view = dataset.match(F('individual_cluster') == cid)
        samples = list(view.shuffle(seed=cid).limit(max_per_individual))
        print(f'individual_{cid}: showing {len(samples)} of {view.count()}')
        if len(samples) == 0:
            continue
        fig, axes = plt.subplots(1, len(samples), figsize=(4*len(samples), 4))
        if len(samples) == 1:
            axes = [axes]
        for ax, sample in zip(axes, samples):
            img = Image.open(sample.filepath).convert('RGB')
            ax.imshow(img)
            heat = None
            if sample.has_field('pca_fg_heat') and sample['pca_fg_heat'] is not None:
                heat = sample['pca_fg_heat'].map
            if heat is not None:
                ax.imshow(heat, cmap='inferno', alpha=0.35)
            ax.set_xticks([]); ax.set_yticks([])
        plt.show()

# %% [markdown]
# ## 10. Export clustered images to runs/run_name

# %%
from pathlib import Path
import shutil
from fiftyone import ViewField as F

run_name = 'run1'  # change per run
run_dir = Path('runs') / run_name
pose_dir = run_dir / 'pose_clusters'
indiv_dir = run_dir / 'individuals'
pose_dir.mkdir(parents=True, exist_ok=True)
indiv_dir.mkdir(parents=True, exist_ok=True)

if dataset.has_field('pose_cluster'):
    pose_vals = dataset.values('pose_cluster')
    pose_ids = sorted(set(p for p in pose_vals if p is not None))
    for pid in pose_ids:
        cluster_dir = pose_dir / f'pose_{pid}'
        cluster_dir.mkdir(parents=True, exist_ok=True)
        view = dataset.match(F('pose_cluster') == pid)
        for s in view:
            dest = cluster_dir / f"{s.id}_{Path(s.filepath).name}"
            if not dest.exists():
                shutil.copy2(s.filepath, dest)
    print(f'Saved pose clusters to {pose_dir}')
else:
    print('No pose_cluster field; run pose clustering first.')

if dataset.has_field('individual_cluster'):
    indiv_vals = dataset.values('individual_cluster')
    indiv_ids = sorted(set(c for c in indiv_vals if c is not None))
    for cid in indiv_ids:
        cluster_dir = indiv_dir / f'individual_{cid}'
        cluster_dir.mkdir(parents=True, exist_ok=True)
        view = dataset.match(F('individual_cluster') == cid)
        for s in view:
            dest = cluster_dir / f"{s.id}_{Path(s.filepath).name}"
            if not dest.exists():
                shutil.copy2(s.filepath, dest)
    print(f'Saved individual clusters to {indiv_dir}')
else:
    print('No individual_cluster field; run individual clustering first.')
